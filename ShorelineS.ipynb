# %% [markdown]
# # ShorelineS in BlueMath
# ## Launch the Senegal case located in compiled/input
#
# From MATLAB I can run the example
# ```
# runShorelineS('../compiled/input.txt')
# ```
#
# In this case we show how to lauch ShorelineS using the MATLAB runtime.
#
# To run a custom simulation just create the input file and replace "input.txt" with the name of your file.

# %%
import os

# Change to the compiled directory and run all commands
os.chdir('compiled')

# %%
os.system('chmod +x launchShorelineS.sh runShorelineS.exe')
os.system('./launchShorelineS.sh /opt/matlabruntime/R2025b/ "input.txt" &')
# Out:
# ------------------------------------------
# Setting up environment variables
# ---
# LD_LIBRARY_PATH is .:/opt/matlabruntime/R2025b//runtime/glnxa64:/opt/matlabruntime/R2025b//bin/glnxa64:/opt/matlabruntime/R2025b//sys/os/glnxa64:/opt/matlabruntime/R2025b//sys/opengl/lib/glnxa64
# 0
# fid =
#
#      3
#
#
# s =
#
#     'LDBcoastline='../script/Data/LDB_161/1984-01-09-1984-07-07_IM_L4_UTM_SLini_South.txt'          '
#
#
# s =
#
#     '                                % LDB with initial coastline shape ([Nx2] ASCII FILE WITHOUT HEADER)'
#
#
# s =
#
#     '                                % <- leave empty to use interactive mode!'
#
#
# s =
#
#     'start=0'
#
#
# s =
#
#     'struct=1                     % switch for using hard structures'
#
#
# s =
#
#     'channel=1'
#
#
# s =
#
#     'LDBchannel='../script/Data/Senegal.txt''
#
#
# s =
#
#     'channel_width=[300]'
#
#
# s =
#
#     'channel_fac=0.2'
#
#
# s =
#
#     'x_hard=[337200 337200 350000]'
#
#
# s =
#
#     'y_hard=[1754600 1755100 1755100]'
#
#
# s =
#
#     '% if ~start>0'
#
#
# s =
#
#     '%    load rivermat'
#
#
# s =
#
#     '% end'
#
#
# s =
#
#     '% xr_mc=xr_mc'
#
#
# s =
#
#     '% yr_mc=yr_mc'
#
#
# s =
#
#     '                                % LDB with hard structures ([Nx2] ASCII FILE WITHOUT HEADER) '
#
#
# s =
#
#     '                                % <- leave empty to use interactive mode!'
#
#
# s =
#
#     'wavetransm = [0,0]           % transmission coeficient of the structures'
#
#
# s =
#
#     '                                % array size equal to number of structure'
#
#
# s =
#
#     '                                % sections'
#
#
# s =
#
#     'LDBplot = {'../script/Data/LDB_161/1984-01-09-1984-07-07_IM_L4_UTM.txt','1984','k:'...'
#
#
# s =
#
#     'xlimits=[ 330000  345000]    % x-limits of plot area'
#
#
# s =
#
#     'ylimits=[1745000 1755000]    % y-limits of plot area'
#
#
# s =
#
#     'reftime='1984-04-09'         % Reference time <- leave empty to use t=0'
#
#
# s =
#
#     'endofsimulation='2003-04-01' % End time of simulation'
#
#
# s =
#
#     'outputdir='StLouisCal310'       % output directory for plots and animation'
#
#
# s =
#
#     'Waveclimfile=''              '
#
#
# s =
#
#     '                                % Wave climate file <-leave empty to use wave parameters '
#
#
# s =
#
#     '                                % ('Hso', 'phiw0' and 'spread')'
#
#
# s =
#
#     'Hso_in=1.4                     % deep water wave height(m)'
#
#
# s =
#
#     'Hso=1.4                        % deep water wave height(m)'
#
#
# s =
#
#     'phiw0=310                    % deep water wave angle [ N]'
#
#
# s =
#
#     'spread=60                    % wave spreading [ ] (wave_dir from range:  phiw0 +/- 0.5*spread)'
#
#
# s =
#
#     'WVCfile=''                   % wave time-series <-leave empty to use wave parameters ('Hso', 'phiw0' and 'spread')'
#
#
# s =
#
#     'd=5                         % Active profile height [m]'
#
#
# s =
#
#     'ddeep=30                     % Offshore water depth for refraction'
#
#
# s =
#
#     'dnearshore=6                 % Nearshore water depth for refraction'
#
#
# s =
#
#     'phif=[]                      % Orientation of the foreshore [ N] <- only relevant for 'KAMP', 'MILH' or 'VR14''
#
#
# s =
#
#     'trform='CERC'               % Switch for transport formulation (e.g. trform='CERC', 'KAMP', 'MILH' or 'VR14')'
#
#
# s =
#
#     'b=.5e6                        % CERC : coeff in simple cerc formula'
#
#
# s =
#
#     'tc=.9                       % factor to modify automatic timestep'
#
#
# s =
#
#     'ds0=100                      % initial space step [m]'
#
#
# s =
#
#     'nt=5000                      % number of timesteps'
#
#
# s =
#
#     'growth=0                     % calibration of nourishment growth rate'
#
#
# s =
#
#     'nourish=0                    % switch (0/1) for nourishments'
#
#
# s =
#
#     'LDBnourish=''                % LDB with nourishment locations ([Nx2] ASCII FILE WITHOUT HEADER) (i.e. polygon around relevant grid cells) <- leave empty to use interactive mode!'
#
#
# s =
#
#     'nourrate=100                 % nourishment rate in polygon (m3/m/y)'
#
#
# s =
#
#     'nourstart=0                  % start time of nourishment (y)'
#
#
# s =
#
#     'spit_width=50                 % width of tip of spit'
#
#
# s =
#
#     'twopoints=1                  % upwind treatment involving two points (1) or 1 point (0)'
#
#
# s =
#
#     'plotinterval=10'
#
#
# s =
#
#     'storageinterval=1'
#
#
# s =
#
#     'fignryear=12'
#
#
# s =
#
#     'smoothfac=0.01'
#
#
# s =
#
#     'usefill=0'
#
#
# s =
#
#   0×0 empty char array
#
#
# s =
#
#   0×0 empty char array
#
#
# s =
#
#     -1
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %                  RUN SHORELINES                   %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#   Initialize default values
#    - Warning : 'start' is not a default keyword.
#    - Warning : 'waveclimfile' is not a default keyword.
#    - Warning : 'hsoin' is not a default keyword.
#    - Warning : 'nt' is not a default keyword.
#    - Warning : 'nourstart' is not a default keyword.
#   Initialize time
#   Prepare coastline
#   Prepare dunes
#   Prepare climate change parameters
#   Prepare wave conditions
#   Prepare runup conditions
#   Prepare tide
#   Prepare structures
#   Prepare nourishments
#   Prepare shoreface nourishments
#   Prepare transport
#   Prepare spit
#   Prepare channel
#   Prepare delta
#   Initialize bathy
#   Initialize plot
#   Initialize output data-structures
#   Loop over time

# %% [markdown]
# ## Plot the output as it's being created

# %%
import os
import time
from IPython.display import display, clear_output
from PIL import Image

folder = 'StLouisCal310'

while not os.path.exists(folder):
    print(f"Waiting for folder '{folder}' to be created...")
    time.sleep(1)

while True:
    # Find the newest png file in the folder
    png_files_all = [f for f in os.listdir(folder) if f.endswith('.png')]
    if png_files_all:
        latest_png = max(png_files_all, key=lambda x: os.path.getmtime(os.path.join(folder, x)))
    else:
        latest_png = None
    time.sleep(1)
    if latest_png:
        img_path = os.path.join(folder, latest_png)
        img = Image.open(img_path)
        clear_output(wait=True)
        display(img)
        time.sleep(1)  # Check every second
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1275x850>
